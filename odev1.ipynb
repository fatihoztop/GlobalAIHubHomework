# %%
isim_soyisim = input("Lütfen isminizi ve soyisminizi giriniz: ")
print("İsim: " + isim_soyisim)
yas = int(input("Lütfen yaşınızı giriniz: "))
print("Yaş: " + str(yas))
sehir = input("Yaşadığınız Şehir: ")
print("Şehir: " + sehir)
meslek = input("Mesleğiniz: ")
print(f"Meslek: {meslek}")
tarih = int(input("Dogum Yılınız: "))
print("Dogum Yılı: {}".format(tarih))
# Out:
# Lütfen isminizi ve soyisminizi giriniz:  Fatih Öztop
# İsim: Fatih Öztop
# Lütfen yaşınızı giriniz:  22
# Yaş: 22
# Yaşadığınız Şehir:  Gaziantep
# Şehir: Gaziantep
# Mesleğiniz:  Grafiker
# Meslek: Grafiker
# Dogum Yılınız:  1998
# Dogum Yılı: 1998

# %%
def type_of(x):
    print("Tip {}".format(type(x)))

# %%
type_of(isim_soyisim)
# Out:
# Tip <class 'str'>

# %%
type_of(yas)
# Out:
# Tip <class 'int'>

# %%
type_of(meslek)
# Out:
# Tip <class 'str'>

# %%
type_of(tarih)
# Out:
# Tip <class 'int'>

# %%
type_of(sehir)
# Out:
# Tip <class 'str'>
